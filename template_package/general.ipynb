# %%
import pandas as pd
df = pd.read_csv('data/omnipath_ligrec_curated.csv', index_col=0)

# %%
df.shape
df.head()
# Out:
# (35447, 5)
#    source  target source_genesymbol target_genesymbol   resource
# 1  O00182  P08575            LGALS9             PTPRC  consensus
# 2  O00182  P08581            LGALS9               MET  consensus
# 3  O00182  P16070            LGALS9              CD44  consensus
# 4  O00182  Q07954            LGALS9              LRP1  consensus
# 5  O00182  Q08722            LGALS9              CD47  consensus

# %%
df_human = df[df['resource'] == 'consensus']
df_mouse = df[df['resource'] == 'mouseconsensus']

print(df_human.shape, df_mouse.shape)

df_human.head()
# check if there are duplicated rows
df_mouse.duplicated().sum()
# Out:
# (4701, 5) (3998, 5)
# 0
